# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from pandas.plotting import autocorrelation_plot, lag_plot
import warnings
warnings.filterwarnings('ignore')
import itertools
import statsmodels.api as sm
from matplotlib.pylab import rcParams
plt.style.use('ggplot')
from statsmodels.tsa.stattools import adfuller
import pandas.util.testing as tm

# %%
df=pd.read_csv('zillow_data.csv')
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
df_new=df.drop(columns=['RegionID', 'SizeRank', 'Metro', 'CountyName'])
df_new.head()
# Out:
#    RegionName      City State   1996-04   1996-05   1996-06   1996-07  \
# 0       60657   Chicago    IL  334200.0  335400.0  336500.0  337600.0
# 1       75070  McKinney    TX  235700.0  236900.0  236700.0  235400.0
# 2       77494      Katy    TX  210400.0  212200.0  212200.0  210700.0
# 3       60614   Chicago    IL  498100.0  500900.0  503100.0  504600.0
# 4       79936   El Paso    TX   77300.0   77300.0   77300.0   77300.0
#
#     1996-08   1996-09   1996-10  ...  2017-07  2017-08  2017-09  2017-10  \
# 0  338500.0  339500.0  340400.0  ...  1005500  1007500  1007800  1009600
# 1  233300.0  230600.0  227300.0  ...   308000   310000   312500   314100
# 2  208300.0  205500.0  202500.0  ...   321000   320600   320200   320400
# 3  505500.0  505700.0  505300.0  ...  1289800  1287700  1287400  1291500
# 4   77400.0   77500.0   77600.0  ...   119100   119400   120000   120300
#
#    2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1013300  1018700  1024400  1030700  1033800  1030600
# 1   315000   316600   318100   319600   321100   321800
# 2   320800   321200   321200   323000   326900   329900
# 3  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120500   121000   121500
#
# [5 rows x 268 columns]

# %%
def melt_data(df):
    melted = pd.melt(df, id_vars=['RegionName',  'City', 'State'], 
                     var_name='Date')
    melted['Date'] = pd.to_datetime(melted['Date'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted
df_dates = melt_data(df_new)
df_dates.head()
# Out:
#    RegionName      City State       Date     value
# 0       60657   Chicago    IL 1996-04-01  334200.0
# 1       75070  McKinney    TX 1996-04-01  235700.0
# 2       77494      Katy    TX 1996-04-01  210400.0
# 3       60614   Chicago    IL 1996-04-01  498100.0
# 4       79936   El Paso    TX 1996-04-01   77300.0

# %%
df_dates.set_index('Date', inplace = True)

recent = df_dates.loc['2013-01-01':'2018-04-01']
tx = recent[recent['State'] == 'TX']
austin_df = tx[tx['City'] == 'Austin']
austin_df.head()
# Out:
#             RegionName    City State     value
# Date
# 2013-01-01       78704  Austin    TX  383200.0
# 2013-01-01       78745  Austin    TX  177500.0
# 2013-01-01       78758  Austin    TX  142400.0
# 2013-01-01       78741  Austin    TX  141100.0
# 2013-01-01       78753  Austin    TX  133600.0

# %%
zips_grouped = austin_df.groupby(['RegionName'], as_index = True).resample('M').sum()
zips_grouped.drop(columns = 'RegionName', inplace=True)
zips_grouped.head()
# Out:
#                           value
# RegionName Date
# 78617      2013-01-31  121000.0
#            2013-02-28  120700.0
#            2013-03-31  120600.0
#            2013-04-30  120800.0
#            2013-05-31  121200.0

# %%
temp_monthly = austin_df.drop(columns=['RegionName', 'City', 'State']).resample('MS')
month_mean = temp_monthly.mean()
plt.plot(month_mean);

# %%
austin_codes = austin_df.RegionName.unique()
austin_codes
# Out:
# array([78704, 78745, 78758, 78741, 78753, 78759, 78748, 78744, 78749,
#        78723, 78727, 78717, 78731, 78705, 78703, 78728, 78750, 78746,
#        78757, 78702, 78751, 78735, 78754, 78752, 78617, 78724, 78747,
#        78737, 78739, 78726, 78732, 78756, 78721, 78730, 78736, 78733,
#        78722, 78725])

# %%
zip_group_list = []
for x in austin_codes:
    zip_group = zips_grouped.loc[x]
    zip_group_list.append([x, zip_group])
zip_group_list
# Out:
# [[78704,                value
#   Date
#   2013-01-31  383200.0
#   2013-02-28  385900.0
#   2013-03-31  388000.0
#   2013-04-30  390300.0
#   2013-05-31  392800.0
#   ...              ...
#   2017-12-31  539800.0
#   2018-01-31  540200.0
#   2018-02-28  542300.0
#   2018-03-31  547100.0
#   2018-04-30  550900.0
#
#   [64 rows x 1 columns]], [78745,                value
#   Date
#   2013-01-31  177500.0
#   2013-02-28  178800.0
#   2013-03-31  180000.0
#   2013-04-30  181400.0
#   2013-05-31  183000.0
#   ...              ...
#   2017-12-31  290500.0
#   2018-01-31  291300.0
#   2018-02-28  292600.0
#   2018-03-31  294000.0
#   2018-04-30  294700.0
#
#   [64 rows x 1 columns]], [78758,                value
#   Date
#   2013-01-31  142400.0
#   2013-02-28  143800.0
#   2013-03-31  145200.0
#   2013-04-30  146300.0
#   2013-05-31  147100.0
#   ...              ...
#   2017-12-31  250500.0
#   2018-01-31  255100.0
#   2018-02-28  260100.0
#   2018-03-31  266000.0
#   2018-04-30  270400.0
#
#   [64 rows x 1 columns]], [78741,                value
#   Date
#   2013-01-31  141100.0
#   2013-02-28  141500.0
#   2013-03-31  141800.0
#   2013-04-30  142200.0
#   2013-05-31  143100.0
#   ...              ...
#   2017-12-31  238300.0
#   2018-01-31  241000.0
#   2018-02-28  243600.0
#   2018-03-31  247400.0
#   2018-04-30  250400.0
#
#   [64 rows x 1 columns]], [78753,                value
#   Date
#   2013-01-31  133600.0
#   2013-02-28  134700.0
#   2013-03-31  135600.0
#   2013-04-30  136600.0
#   2013-05-31  137500.0
#   ...              ...
#   2017-12-31  225000.0
#   2018-01-31  227100.0
#   2018-02-28  228700.0
#   2018-03-31  231500.0
#   2018-04-30  233400.0
#
#   [64 rows x 1 columns]], [78759,                value
#   Date
#   2013-01-31  308600.0
#   2013-02-28  309700.0
#   2013-03-31  309800.0
#   2013-04-30  310000.0
#   2013-05-31  311900.0
#   ...              ...
#   2017-12-31  442400.0
#   2018-01-31  443200.0
#   2018-02-28  445000.0
#   2018-03-31  449900.0
#   2018-04-30  454100.0
#
#   [64 rows x 1 columns]], [78748,                value
#   Date
#   2013-01-31  185400.0
#   2013-02-28  186200.0
#   2013-03-31  186700.0
#   2013-04-30  187600.0
#   2013-05-31  189300.0
#   ...              ...
#   2017-12-31  276700.0
#   2018-01-31  277800.0
#   2018-02-28  279000.0
#   2018-03-31  280800.0
#   2018-04-30  282000.0
#
#   [64 rows x 1 columns]], [78744,                value
#   Date
#   2013-01-31  111300.0
#   2013-02-28  111200.0
#   2013-03-31  111000.0
#   2013-04-30  110900.0
#   2013-05-31  111000.0
#   ...              ...
#   2017-12-31  190900.0
#   2018-01-31  192100.0
#   2018-02-28  193200.0
#   2018-03-31  194500.0
#   2018-04-30  195500.0
#
#   [64 rows x 1 columns]], [78749,                value
#   Date
#   2013-01-31  243400.0
#   2013-02-28  245000.0
#   2013-03-31  245600.0
#   2013-04-30  246100.0
#   2013-05-31  247800.0
#   ...              ...
#   2017-12-31  348900.0
#   2018-01-31  349700.0
#   2018-02-28  352100.0
#   2018-03-31  355500.0
#   2018-04-30  357700.0
#
#   [64 rows x 1 columns]], [78723,                value
#   Date
#   2013-01-31  214300.0
#   2013-02-28  219400.0
#   2013-03-31  224700.0
#   2013-04-30  229600.0
#   2013-05-31  233900.0
#   ...              ...
#   2017-12-31  352500.0
#   2018-01-31  355800.0
#   2018-02-28  358700.0
#   2018-03-31  361900.0
#   2018-04-30  364200.0
#
#   [64 rows x 1 columns]], [78727,                value
#   Date
#   2013-01-31  195300.0
#   2013-02-28  196000.0
#   2013-03-31  196300.0
#   2013-04-30  197100.0
#   2013-05-31  198300.0
#   ...              ...
#   2017-12-31  309300.0
#   2018-01-31  311800.0
#   2018-02-28  313400.0
#   2018-03-31  315200.0
#   2018-04-30  316500.0
#
#   [64 rows x 1 columns]], [78717,                value
#   Date
#   2013-01-31  254700.0
#   2013-02-28  256200.0
#   2013-03-31  257900.0
#   2013-04-30  260100.0
#   2013-05-31  262100.0
#   ...              ...
#   2017-12-31  355100.0
#   2018-01-31  356600.0
#   2018-02-28  359500.0
#   2018-03-31  362300.0
#   2018-04-30  363600.0
#
#   [64 rows x 1 columns]], [78731,                value
#   Date
#   2013-01-31  454300.0
#   2013-02-28  456000.0
#   2013-03-31  457400.0
#   2013-04-30  458400.0
#   2013-05-31  460200.0
#   ...              ...
#   2017-12-31  581700.0
#   2018-01-31  578400.0
#   2018-02-28  581900.0
#   2018-03-31  596700.0
#   2018-04-30  610500.0
#
#   [64 rows x 1 columns]], [78705,                value
#   Date
#   2013-01-31  415400.0
#   2013-02-28  419700.0
#   2013-03-31  421700.0
#   2013-04-30  421100.0
#   2013-05-31  418200.0
#   ...              ...
#   2017-12-31  483200.0
#   2018-01-31  484300.0
#   2018-02-28  489100.0
#   2018-03-31  501200.0
#   2018-04-30  511600.0
#
#   [64 rows x 1 columns]], [78703,                value
#   Date
#   2013-01-31  570200.0
#   2013-02-28  573700.0
#   2013-03-31  577800.0
#   2013-04-30  581400.0
#   2013-05-31  586800.0
#   ...              ...
#   2017-12-31  876700.0
#   2018-01-31  875900.0
#   2018-02-28  880100.0
#   2018-03-31  884600.0
#   2018-04-30  885300.0
#
#   [64 rows x 1 columns]], [78728,                value
#   Date
#   2013-01-31  176700.0
#   2013-02-28  177700.0
#   2013-03-31  178300.0
#   2013-04-30  178700.0
#   2013-05-31  179100.0
#   ...              ...
#   2017-12-31  260600.0
#   2018-01-31  260700.0
#   2018-02-28  262300.0
#   2018-03-31  265000.0
#   2018-04-30  266500.0
#
#   [64 rows x 1 columns]], [78750,                value
#   Date
#   2013-01-31  302400.0
#   2013-02-28  303400.0
#   2013-03-31  304400.0
#   2013-04-30  305500.0
#   2013-05-31  307400.0
#   ...              ...
#   2017-12-31  437100.0
#   2018-01-31  439100.0
#   2018-02-28  442400.0
#   2018-03-31  446100.0
#   2018-04-30  448200.0
#
#   [64 rows x 1 columns]], [78746,                value
#   Date
#   2013-01-31  626600.0
#   2013-02-28  629600.0
#   2013-03-31  630900.0
#   2013-04-30  635200.0
#   2013-05-31  645900.0
#   ...              ...
#   2017-12-31  909000.0
#   2018-01-31  912600.0
#   2018-02-28  917200.0
#   2018-03-31  921200.0
#   2018-04-30  918700.0
#
#   [64 rows x 1 columns]], [78757,                value
#   Date
#   2013-01-31  284900.0
#   2013-02-28  287000.0
#   2013-03-31  288300.0
#   2013-04-30  289300.0
#   2013-05-31  290800.0
#   ...              ...
#   2017-12-31  420600.0
#   2018-01-31  424000.0
#   2018-02-28  426300.0
#   2018-03-31  427900.0
#   2018-04-30  428500.0
#
#   [64 rows x 1 columns]], [78702,                value
#   Date
#   2013-01-31  236100.0
#   2013-02-28  237800.0
#   2013-03-31  239000.0
#   2013-04-30  239200.0
#   2013-05-31  240300.0
#   ...              ...
#   2017-12-31  405200.0
#   2018-01-31  410100.0
#   2018-02-28  413800.0
#   2018-03-31  417300.0
#   2018-04-30  419800.0
#
#   [64 rows x 1 columns]], [78751,                value
#   Date
#   2013-01-31  294800.0
#   2013-02-28  297600.0
#   2013-03-31  299900.0
#   2013-04-30  301900.0
#   2013-05-31  303400.0
#   ...              ...
#   2017-12-31  434500.0
#   2018-01-31  436100.0
#   2018-02-28  437600.0
#   2018-03-31  441200.0
#   2018-04-30  444500.0
#
#   [64 rows x 1 columns]], [78735,                value
#   Date
#   2013-01-31  373600.0
#   2013-02-28  377500.0
#   2013-03-31  380500.0
#   2013-04-30  382900.0
#   2013-05-31  385900.0
#   ...              ...
#   2017-12-31  473200.0
#   2018-01-31  473500.0
#   2018-02-28  475500.0
#   2018-03-31  479300.0
#   2018-04-30  482200.0
#
#   [64 rows x 1 columns]], [78754,                value
#   Date
#   2013-01-31  163400.0
#   2013-02-28  163700.0
#   2013-03-31  163900.0
#   2013-04-30  164600.0
#   2013-05-31  165900.0
#   ...              ...
#   2017-12-31  235500.0
#   2018-01-31  235100.0
#   2018-02-28  235700.0
#   2018-03-31  238300.0
#   2018-04-30  240600.0
#
#   [64 rows x 1 columns]], [78752,                value
#   Date
#   2013-01-31  183800.0
#   2013-02-28  184600.0
#   2013-03-31  185900.0
#   2013-04-30  187800.0
#   2013-05-31  190100.0
#   ...              ...
#   2017-12-31  299300.0
#   2018-01-31  300400.0
#   2018-02-28  301400.0
#   2018-03-31  302300.0
#   2018-04-30  303100.0
#
#   [64 rows x 1 columns]], [78617,                value
#   Date
#   2013-01-31  121000.0
#   2013-02-28  120700.0
#   2013-03-31  120600.0
#   2013-04-30  120800.0
#   2013-05-31  121200.0
#   ...              ...
#   2017-12-31  182100.0
#   2018-01-31  183100.0
#   2018-02-28  184300.0
#   2018-03-31  186000.0
#   2018-04-30  187100.0
#
#   [64 rows x 1 columns]], [78724,                value
#   Date
#   2013-01-31  111000.0
#   2013-02-28  111100.0
#   2013-03-31  111400.0
#   2013-04-30  112300.0
#   2013-05-31  113400.0
#   ...              ...
#   2017-12-31  185300.0
#   2018-01-31  186400.0
#   2018-02-28  187900.0
#   2018-03-31  189100.0
#   2018-04-30  189300.0
#
#   [64 rows x 1 columns]], [78747,                value
#   Date
#   2013-01-31  170100.0
#   2013-02-28  171100.0
#   2013-03-31  171700.0
#   2013-04-30  171300.0
#   2013-05-31  170900.0
#   ...              ...
#   2017-12-31  243800.0
#   2018-01-31  244800.0
#   2018-02-28  246600.0
#   2018-03-31  249300.0
#   2018-04-30  251200.0
#
#   [64 rows x 1 columns]], [78737,                value
#   Date
#   2013-01-31  316600.0
#   2013-02-28  317900.0
#   2013-03-31  317700.0
#   2013-04-30  316600.0
#   2013-05-31  316300.0
#   ...              ...
#   2017-12-31  438300.0
#   2018-01-31  439200.0
#   2018-02-28  442400.0
#   2018-03-31  447400.0
#   2018-04-30  450400.0
#
#   [64 rows x 1 columns]], [78739,                value
#   Date
#   2013-01-31  328100.0
#   2013-02-28  330700.0
#   2013-03-31  332700.0
#   2013-04-30  336100.0
#   2013-05-31  342400.0
#   ...              ...
#   2017-12-31  448900.0
#   2018-01-31  449500.0
#   2018-02-28  450400.0
#   2018-03-31  451300.0
#   2018-04-30  451000.0
#
#   [64 rows x 1 columns]], [78726,                value
#   Date
#   2013-01-31  327700.0
#   2013-02-28  327900.0
#   2013-03-31  328100.0
#   2013-04-30  328700.0
#   2013-05-31  329700.0
#   ...              ...
#   2017-12-31  437600.0
#   2018-01-31  437900.0
#   2018-02-28  438900.0
#   2018-03-31  441600.0
#   2018-04-30  444100.0
#
#   [64 rows x 1 columns]], [78732,                value
#   Date
#   2013-01-31  379900.0
#   2013-02-28  380500.0
#   2013-03-31  381100.0
#   2013-04-30  383200.0
#   2013-05-31  386200.0
#   ...              ...
#   2017-12-31  465300.0
#   2018-01-31  465500.0
#   2018-02-28  466300.0
#   2018-03-31  468800.0
#   2018-04-30  471500.0
#
#   [64 rows x 1 columns]], [78756,                value
#   Date
#   2013-01-31  357100.0
#   2013-02-28  357900.0
#   2013-03-31  358800.0
#   2013-04-30  359900.0
#   2013-05-31  363000.0
#   ...              ...
#   2017-12-31  476000.0
#   2018-01-31  476600.0
#   2018-02-28  478700.0
#   2018-03-31  483400.0
#   2018-04-30  487400.0
#
#   [64 rows x 1 columns]], [78721,                value
#   Date
#   2013-01-31  141100.0
#   2013-02-28  141700.0
#   2013-03-31  143300.0
#   2013-04-30  144800.0
#   2013-05-31  146300.0
#   ...              ...
#   2017-12-31  293000.0
#   2018-01-31  296300.0
#   2018-02-28  297800.0
#   2018-03-31  297200.0
#   2018-04-30  296100.0
#
#   [64 rows x 1 columns]], [78730,                value
#   Date
#   2013-01-31  472700.0
#   2013-02-28  473300.0
#   2013-03-31  472900.0
#   2013-04-30  472600.0
#   2013-05-31  473700.0
#   ...              ...
#   2017-12-31  664800.0
#   2018-01-31  667600.0
#   2018-02-28  669700.0
#   2018-03-31  677000.0
#   2018-04-30  683700.0
#
#   [64 rows x 1 columns]], [78736,                value
#   Date
#   2013-01-31  230100.0
#   2013-02-28  230100.0
#   2013-03-31  229800.0
#   2013-04-30  229500.0
#   2013-05-31  230200.0
#   ...              ...
#   2017-12-31  328100.0
#   2018-01-31  328400.0
#   2018-02-28  332600.0
#   2018-03-31  339900.0
#   2018-04-30  344900.0
#
#   [64 rows x 1 columns]], [78733,                value
#   Date
#   2013-01-31  446600.0
#   2013-02-28  448000.0
#   2013-03-31  449100.0
#   2013-04-30  450500.0
#   2013-05-31  452900.0
#   ...              ...
#   2017-12-31  579400.0
#   2018-01-31  583900.0
#   2018-02-28  593400.0
#   2018-03-31  607300.0
#   2018-04-30  615600.0
#
#   [64 rows x 1 columns]], [78722,                value
#   Date
#   2013-01-31  271400.0
#   2013-02-28  272900.0
#   2013-03-31  273100.0
#   2013-04-30  274800.0
#   2013-05-31  279000.0
#   ...              ...
#   2017-12-31  403300.0
#   2018-01-31  405200.0
#   2018-02-28  408400.0
#   2018-03-31  413900.0
#   2018-04-30  417500.0
#
#   [64 rows x 1 columns]], [78725,                value
#   Date
#   2013-01-31  116800.0
#   2013-02-28  117300.0
#   2013-03-31  117800.0
#   2013-04-30  118300.0
#   2013-05-31  118500.0
#   ...              ...
#   2017-12-31  185000.0
#   2018-01-31  186000.0
#   2018-02-28  187000.0
#   2018-03-31  187700.0
#   2018-04-30  188200.0
#
#   [64 rows x 1 columns]]]

# %%
def calculate_roi_5(ts):
    roi_5 = (ts - ts.shift(periods=60))/ts.shift(periods=60)*100
    return roi_5

roi_df = pd.DataFrame(columns=['zipcode', 'roi_5'])

for zipcode in zip_group_list:
    roi_5 = calculate_roi_5(zipcode[1])
    roi_5.dropna(inplace=True)
    roi_df.loc[len(roi_df.index)] = [zipcode[0], roi_5.iloc[0][0]] 
roi_df.head()
# Out:
#    zipcode      roi_5
# 0  78704.0  40.970772
# 1  78745.0  64.112676
# 2  78758.0  79.143258
# 3  78741.0  70.800850
# 4  78753.0  69.985030

# %%
roi_sorted_df = roi_df.sort_values(['roi_5'], ascending=False)
roi_sorted_df.head()
# Out:
#     zipcode       roi_5
# 32  78721.0  109.992913
# 2   78758.0   79.143258
# 19  78702.0   73.697586
# 7   78744.0   72.596586
# 3   78741.0   70.800850

# %%
top_ten_zips = []
for i in range(0, 10):
    top_ten_zips.append(int(roi_sorted_df.iloc[i][0]))
top_ten_zips
# Out:
# [78721, 78758, 78702, 78744, 78741, 78753, 78724, 78723, 78745, 78752]

# %%
# acf and pacf function

def plot_acf_pacf(ts, zipcode, figsize=(10,8), lags = 12):
    fig,ax = plt.subplots(nrows=3, figsize = figsize)
    
    #plot time series
    ts.plot(ax=ax[0])
    
    #plot acf, pacf
    plot_acf(ts,ax=ax[1], lags=lags)
    plot_pacf(ts, ax=ax[2], lags=lags)
    fig.tight_layout()
    
    fig.suptitle(f'Zipcode: {zipcode}',y=1.1, fontsize=20)
    
    for a in ax[1:]:
        a.xaxis.set_major_locator(matplotlib.ticker.MaxNLocator(min_n_ticks=lags, integer = True))
        a.xaxis.grid()
    return fig,ax

# %%
zip_78721 = zips_grouped.loc[78721]
plot_acf_pacf(zip_78721, 78721)
plt.show()

# %%
decompose_result = seasonal_decompose(zip_78721, model="additive")

trend = decompose_result.trend
seasonal = decompose_result.seasonal
residual = decompose_result.resid

decompose_result.plot();

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 3)

# Generate all different combinations of p, q and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, q and q triplets
pdqs = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
# Run a grid with pdq and seasonal pdq parameters calculated above and get the best AIC value
ans = []
for comb in pdq:
    for combs in pdqs:
        try:
            mod = sm.tsa.statespace.SARIMAX(zip_78721,
                                            order=comb,
                                            seasonal_order=combs,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            output = mod.fit()
            ans.append([comb, combs, output.aic])
            print('ARIMA {} x {}12 : AIC Calculated ={}'.format(comb, combs, output.aic))
        except:
            continue
# Out:
# ARIMA (0, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =1732.4393222305996
# ARIMA (0, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =1385.8860191136334
# ARIMA (0, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =1207.291537828405
# ARIMA (0, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =916.8158858103315
# ARIMA (0, 0, 0) x (0, 2, 0, 12)12 : AIC Calculated =863.1687539700204
# ARIMA (0, 0, 0) x (0, 2, 1, 12)12 : AIC Calculated =1354.8172183755216
# ARIMA (0, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =1099.258678273307
# ARIMA (0, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =1087.2241670384356
# ARIMA (0, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =884.2759659703605
# ARIMA (0, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =1208.5523097291266
# ARIMA (0, 0, 0) x (1, 2, 0, 12)12 : AIC Calculated =618.542006785905
# ARIMA (0, 0, 0) x (1, 2, 1, 12)12 : AIC Calculated =592.2325355504713
# ARIMA (0, 0, 0) x (2, 0, 0, 12)12 : AIC Calculated =821.4144630417628
# ARIMA (0, 0, 0) x (2, 0, 1, 12)12 : AIC Calculated =820.0154862702011
# ARIMA (0, 0, 0) x (2, 1, 0, 12)12 : AIC Calculated =604.917230039653
# ARIMA (0, 0, 0) x (2, 1, 1, 12)12 : AIC Calculated =608.9600267544856
# ARIMA (0, 0, 0) x (2, 2, 0, 12)12 : AIC Calculated =338.5405302243561
# ARIMA (0, 0, 0) x (2, 2, 1, 12)12 : AIC Calculated =329.4455131513803
# ARIMA (0, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =1663.6501480769375
# ARIMA (0, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =1336.1971955502102
# ARIMA (0, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =1197.5878082845613
# ARIMA (0, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =873.7596993009297
# ARIMA (0, 0, 1) x (0, 2, 0, 12)12 : AIC Calculated =822.3353150682401
# ARIMA (0, 0, 1) x (0, 2, 1, 12)12 : AIC Calculated =nan
# ARIMA (0, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =1383.8365812139023
# ARIMA (0, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =1410.6023176680046
# ARIMA (0, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =916.0653123735789
# ARIMA (0, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =885.2721507497129
# ARIMA (0, 0, 1) x (1, 2, 0, 12)12 : AIC Calculated =608.3600864252298
# ARIMA (0, 0, 1) x (1, 2, 1, 12)12 : AIC Calculated =563.0057444209045
# ARIMA (0, 0, 1) x (2, 0, 0, 12)12 : AIC Calculated =1067.8523380728093
# ARIMA (0, 0, 1) x (2, 0, 1, 12)12 : AIC Calculated =1069.849094904324
# ARIMA (0, 0, 1) x (2, 1, 0, 12)12 : AIC Calculated =643.6666376540794
# ARIMA (0, 0, 1) x (2, 1, 1, 12)12 : AIC Calculated =643.522247210777
# ARIMA (0, 0, 1) x (2, 2, 0, 12)12 : AIC Calculated =347.49592241656507
# ARIMA (0, 0, 1) x (2, 2, 1, 12)12 : AIC Calculated =348.8232215667206
# ARIMA (0, 0, 2) x (0, 0, 0, 12)12 : AIC Calculated =1630.3393645637743
# ARIMA (0, 0, 2) x (0, 0, 1, 12)12 : AIC Calculated =1372.1264639192095
# ARIMA (0, 0, 2) x (0, 1, 0, 12)12 : AIC Calculated =1168.0409880967288
# ARIMA (0, 0, 2) x (0, 1, 1, 12)12 : AIC Calculated =880.138137041595
# ARIMA (0, 0, 2) x (0, 2, 0, 12)12 : AIC Calculated =796.1337727409308
# ARIMA (0, 0, 2) x (0, 2, 1, 12)12 : AIC Calculated =2224.441795699767
# ARIMA (0, 0, 2) x (1, 0, 0, 12)12 : AIC Calculated =1387.651058175293
# ARIMA (0, 0, 2) x (1, 0, 1, 12)12 : AIC Calculated =1373.2498462026908
# ARIMA (0, 0, 2) x (1, 1, 0, 12)12 : AIC Calculated =917.8412392596122
# ARIMA (0, 0, 2) x (1, 1, 1, 12)12 : AIC Calculated =849.7424531647317
# ARIMA (0, 0, 2) x (1, 2, 0, 12)12 : AIC Calculated =604.7383566519608
# ARIMA (0, 0, 2) x (1, 2, 1, 12)12 : AIC Calculated =539.9645855576302
# ARIMA (0, 0, 2) x (2, 0, 0, 12)12 : AIC Calculated =1095.7190491720276
# ARIMA (0, 0, 2) x (2, 0, 1, 12)12 : AIC Calculated =1073.246248026699
# ARIMA (0, 0, 2) x (2, 1, 0, 12)12 : AIC Calculated =644.4111090799961
# ARIMA (0, 0, 2) x (2, 1, 1, 12)12 : AIC Calculated =645.5515268391684
# ARIMA (0, 0, 2) x (2, 2, 0, 12)12 : AIC Calculated =349.3070473499232
# ARIMA (0, 0, 2) x (2, 2, 1, 12)12 : AIC Calculated =350.91469517625785
# ARIMA (0, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =1166.6601088471855
# ARIMA (0, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =916.9671756910734
# ARIMA (0, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =907.2770698444543
# ARIMA (0, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =698.8548693771878
# ARIMA (0, 1, 0) x (0, 2, 0, 12)12 : AIC Calculated =731.7543934220795
# ARIMA (0, 1, 0) x (0, 2, 1, 12)12 : AIC Calculated =1090.1811103125003
# ARIMA (0, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =921.476774983788
# ARIMA (0, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =910.7708245463542
# ARIMA (0, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =713.487872167116
# ARIMA (0, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =701.8569041372207
# ARIMA (0, 1, 0) x (1, 2, 0, 12)12 : AIC Calculated =516.9757065363821
# ARIMA (0, 1, 0) x (1, 2, 1, 12)12 : AIC Calculated =1040.8328586785126
# ARIMA (0, 1, 0) x (2, 0, 0, 12)12 : AIC Calculated =714.7409698199411
# ARIMA (0, 1, 0) x (2, 0, 1, 12)12 : AIC Calculated =717.3098282750534
# ARIMA (0, 1, 0) x (2, 1, 0, 12)12 : AIC Calculated =499.2147215518674
# ARIMA (0, 1, 0) x (2, 1, 1, 12)12 : AIC Calculated =500.9568938955814
# ARIMA (0, 1, 0) x (2, 2, 0, 12)12 : AIC Calculated =286.54166648964485
# ARIMA (0, 1, 0) x (2, 2, 1, 12)12 : AIC Calculated =575.1019203316664
# ARIMA (0, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =1077.838450827952
# ARIMA (0, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =855.6554868884675
# ARIMA (0, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =874.5718578326297
# ARIMA (0, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =655.1093118790812
# ARIMA (0, 1, 1) x (0, 2, 0, 12)12 : AIC Calculated =699.4559264520442
# ARIMA (0, 1, 1) x (0, 2, 1, 12)12 : AIC Calculated =1046.0187148799196
# ARIMA (0, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =921.8704572688282
# ARIMA (0, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =882.2350148942876
# ARIMA (0, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =689.0140498781369
# ARIMA (0, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =652.8732479991716
# ARIMA (0, 1, 1) x (1, 2, 0, 12)12 : AIC Calculated =514.3796082456014
# ARIMA (0, 1, 1) x (1, 2, 1, 12)12 : AIC Calculated =839.9942582896508
# ARIMA (0, 1, 1) x (2, 0, 0, 12)12 : AIC Calculated =684.3837733700168
# ARIMA (0, 1, 1) x (2, 0, 1, 12)12 : AIC Calculated =705.6278588362061
# ARIMA (0, 1, 1) x (2, 1, 0, 12)12 : AIC Calculated =482.3891567587893
# ARIMA (0, 1, 1) x (2, 1, 1, 12)12 : AIC Calculated =481.766252810315
# ARIMA (0, 1, 1) x (2, 2, 0, 12)12 : AIC Calculated =281.16062270063003
# ARIMA (0, 1, 1) x (2, 2, 1, 12)12 : AIC Calculated =627.3187773856652
# ARIMA (0, 1, 2) x (0, 0, 0, 12)12 : AIC Calculated =1007.1321062428199
# ARIMA (0, 1, 2) x (0, 0, 1, 12)12 : AIC Calculated =804.6422901739916
# ARIMA (0, 1, 2) x (0, 1, 0, 12)12 : AIC Calculated =844.5065362986647
# ARIMA (0, 1, 2) x (0, 1, 1, 12)12 : AIC Calculated =619.8460688185666
# ARIMA (0, 1, 2) x (0, 2, 0, 12)12 : AIC Calculated =673.1399072882364
# ARIMA (0, 1, 2) x (0, 2, 1, 12)12 : AIC Calculated =953.1979137466152
# ARIMA (0, 1, 2) x (1, 0, 0, 12)12 : AIC Calculated =910.1467281647194
# ARIMA (0, 1, 2) x (1, 0, 1, 12)12 : AIC Calculated =806.6369977854256
# ARIMA (0, 1, 2) x (1, 1, 0, 12)12 : AIC Calculated =676.8453839874965
# ARIMA (0, 1, 2) x (1, 1, 1, 12)12 : AIC Calculated =650.64874453269
# ARIMA (0, 1, 2) x (1, 2, 0, 12)12 : AIC Calculated =497.22868995098884
# ARIMA (0, 1, 2) x (1, 2, 1, 12)12 : AIC Calculated =984.8120801344619
# ARIMA (0, 1, 2) x (2, 0, 0, 12)12 : AIC Calculated =699.5704248942484
# ARIMA (0, 1, 2) x (2, 0, 1, 12)12 : AIC Calculated =662.9051675536864
# ARIMA (0, 1, 2) x (2, 1, 0, 12)12 : AIC Calculated =466.8676231757789
# ARIMA (0, 1, 2) x (2, 1, 1, 12)12 : AIC Calculated =505.8796553269917
# ARIMA (0, 1, 2) x (2, 2, 0, 12)12 : AIC Calculated =283.88137217146453
# ARIMA (0, 1, 2) x (2, 2, 1, 12)12 : AIC Calculated =529.4643582338706
# ARIMA (0, 2, 0) x (0, 0, 0, 12)12 : AIC Calculated =1029.5010477215258
# ARIMA (0, 2, 0) x (0, 0, 1, 12)12 : AIC Calculated =835.4825226213867
# ARIMA (0, 2, 0) x (0, 1, 0, 12)12 : AIC Calculated =858.1012424467245
# ARIMA (0, 2, 0) x (0, 1, 1, 12)12 : AIC Calculated =655.7775614027394
# ARIMA (0, 2, 0) x (0, 2, 0, 12)12 : AIC Calculated =689.0503456384215
# ARIMA (0, 2, 0) x (0, 2, 1, 12)12 : AIC Calculated =947.9305651685596
# ARIMA (0, 2, 0) x (1, 0, 0, 12)12 : AIC Calculated =851.5252902809266
# ARIMA (0, 2, 0) x (1, 0, 1, 12)12 : AIC Calculated =837.480939202949
# ARIMA (0, 2, 0) x (1, 1, 0, 12)12 : AIC Calculated =668.884768922704
# ARIMA (0, 2, 0) x (1, 1, 1, 12)12 : AIC Calculated =653.827262460648
# ARIMA (0, 2, 0) x (1, 2, 0, 12)12 : AIC Calculated =477.29458511617645
# ARIMA (0, 2, 0) x (1, 2, 1, 12)12 : AIC Calculated =925.0679922088486
# ARIMA (0, 2, 0) x (2, 0, 0, 12)12 : AIC Calculated =653.4498903430969
# ARIMA (0, 2, 0) x (2, 0, 1, 12)12 : AIC Calculated =653.8960776257742
# ARIMA (0, 2, 0) x (2, 1, 0, 12)12 : AIC Calculated =462.9696435606172
# ARIMA (0, 2, 0) x (2, 1, 1, 12)12 : AIC Calculated =477.64690881468647
# ARIMA (0, 2, 0) x (2, 2, 0, 12)12 : AIC Calculated =256.5701959924347
# ARIMA (0, 2, 0) x (2, 2, 1, 12)12 : AIC Calculated =2.0178803063094304e+17
# ARIMA (0, 2, 1) x (0, 0, 0, 12)12 : AIC Calculated =1005.0091874311437
# ARIMA (0, 2, 1) x (0, 0, 1, 12)12 : AIC Calculated =804.9202176563573
# ARIMA (0, 2, 1) x (0, 1, 0, 12)12 : AIC Calculated =839.8156542519212
# ARIMA (0, 2, 1) x (0, 1, 1, 12)12 : AIC Calculated =634.5325064981434
# ARIMA (0, 2, 1) x (0, 2, 0, 12)12 : AIC Calculated =671.7360216794523
# ARIMA (0, 2, 1) x (0, 2, 1, 12)12 : AIC Calculated =nan
# ARIMA (0, 2, 1) x (1, 0, 0, 12)12 : AIC Calculated =837.1737236587181
# ARIMA (0, 2, 1) x (1, 0, 1, 12)12 : AIC Calculated =806.6143281533268
# ARIMA (0, 2, 1) x (1, 1, 0, 12)12 : AIC Calculated =670.6746801790653
# ARIMA (0, 2, 1) x (1, 1, 1, 12)12 : AIC Calculated =638.1351427978742
# ARIMA (0, 2, 1) x (1, 2, 0, 12)12 : AIC Calculated =480.876044428365
# ARIMA (0, 2, 1) x (1, 2, 1, 12)12 : AIC Calculated =945.2569898187597
# ARIMA (0, 2, 1) x (2, 0, 0, 12)12 : AIC Calculated =647.7815307262957
# ARIMA (0, 2, 1) x (2, 0, 1, 12)12 : AIC Calculated =657.1877607921524
# ARIMA (0, 2, 1) x (2, 1, 0, 12)12 : AIC Calculated =458.3212476904043
# ARIMA (0, 2, 1) x (2, 1, 1, 12)12 : AIC Calculated =479.5171015213613
# ARIMA (0, 2, 1) x (2, 2, 0, 12)12 : AIC Calculated =258.8258320924931
# ARIMA (0, 2, 1) x (2, 2, 1, 12)12 : AIC Calculated =260.717248220639
# ARIMA (0, 2, 2) x (0, 0, 0, 12)12 : AIC Calculated =983.2233587537359
# ARIMA (0, 2, 2) x (0, 0, 1, 12)12 : AIC Calculated =790.3447406208177
# ARIMA (0, 2, 2) x (0, 1, 0, 12)12 : AIC Calculated =822.2276722487948
# ARIMA (0, 2, 2) x (0, 1, 1, 12)12 : AIC Calculated =615.9068642856557
# ARIMA (0, 2, 2) x (0, 2, 0, 12)12 : AIC Calculated =652.3157603117272
# ARIMA (0, 2, 2) x (0, 2, 1, 12)12 : AIC Calculated =796.810886302659
# ARIMA (0, 2, 2) x (1, 0, 0, 12)12 : AIC Calculated =839.0692711703014
# ARIMA (0, 2, 2) x (1, 0, 1, 12)12 : AIC Calculated =791.4075567922039
# ARIMA (0, 2, 2) x (1, 1, 0, 12)12 : AIC Calculated =668.4974087113314
# ARIMA (0, 2, 2) x (1, 1, 1, 12)12 : AIC Calculated =622.4374341651932
# ARIMA (0, 2, 2) x (1, 2, 0, 12)12 : AIC Calculated =481.66279015397356
# ARIMA (0, 2, 2) x (1, 2, 1, 12)12 : AIC Calculated =903.4588907369786
# ARIMA (0, 2, 2) x (2, 0, 0, 12)12 : AIC Calculated =648.7072188970346
# ARIMA (0, 2, 2) x (2, 0, 1, 12)12 : AIC Calculated =658.0972573946843
# ARIMA (0, 2, 2) x (2, 1, 0, 12)12 : AIC Calculated =459.47339136768585
# ARIMA (0, 2, 2) x (2, 1, 1, 12)12 : AIC Calculated =476.53677714123353
# ARIMA (0, 2, 2) x (2, 2, 0, 12)12 : AIC Calculated =260.828003427191
# ARIMA (0, 2, 2) x (2, 2, 1, 12)12 : AIC Calculated =261.8033340215903
# ARIMA (1, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =1109.335438244712
# ARIMA (1, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =916.7992718338386
# ARIMA (1, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =926.655237934768
# ARIMA (1, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =720.2475396974033
# ARIMA (1, 0, 0) x (0, 2, 0, 12)12 : AIC Calculated =751.7466828252171
# ARIMA (1, 0, 0) x (0, 2, 1, 12)12 : AIC Calculated =1197.0995907917315
# ARIMA (1, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =905.9785558556342
# ARIMA (1, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =918.8004561108547
# ARIMA (1, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =715.6130026329658
# ARIMA (1, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =767.6824006189096
# ARIMA (1, 0, 0) x (1, 2, 0, 12)12 : AIC Calculated =519.1977262122127
# ARIMA (1, 0, 0) x (1, 2, 1, 12)12 : AIC Calculated =520.8153586850883
# ARIMA (1, 0, 0) x (2, 0, 0, 12)12 : AIC Calculated =697.338121632918
# ARIMA (1, 0, 0) x (2, 0, 1, 12)12 : AIC Calculated =699.3368628082451
# ARIMA (1, 0, 0) x (2, 1, 0, 12)12 : AIC Calculated =499.3376920855831
# ARIMA (1, 0, 0) x (2, 1, 1, 12)12 : AIC Calculated =502.8179516527701
# ARIMA (1, 0, 0) x (2, 2, 0, 12)12 : AIC Calculated =270.20972005844845
# ARIMA (1, 0, 0) x (2, 2, 1, 12)12 : AIC Calculated =285.3397705314418
# ARIMA (1, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =1039.7062511978213
# ARIMA (1, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =867.205412723437
# ARIMA (1, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =905.195896312669
# ARIMA (1, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =734.2128250962722
# ARIMA (1, 0, 1) x (0, 2, 0, 12)12 : AIC Calculated =727.57528917643
# ARIMA (1, 0, 1) x (0, 2, 1, 12)12 : AIC Calculated =1211.326817807222
# ARIMA (1, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =862.9942547906224
# ARIMA (1, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =867.0474538514784
# ARIMA (1, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =690.734906836993
# ARIMA (1, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =706.3065641146816
# ARIMA (1, 0, 1) x (1, 2, 0, 12)12 : AIC Calculated =519.0232359021779
# ARIMA (1, 0, 1) x (1, 2, 1, 12)12 : AIC Calculated =500.6251741466902
# ARIMA (1, 0, 1) x (2, 0, 0, 12)12 : AIC Calculated =673.3526742906555
# ARIMA (1, 0, 1) x (2, 0, 1, 12)12 : AIC Calculated =675.4789557187236
# ARIMA (1, 0, 1) x (2, 1, 0, 12)12 : AIC Calculated =484.06742792066063
# ARIMA (1, 0, 1) x (2, 1, 1, 12)12 : AIC Calculated =486.6525005590038
# ARIMA (1, 0, 1) x (2, 2, 0, 12)12 : AIC Calculated =280.9327318708694
# ARIMA (1, 0, 1) x (2, 2, 1, 12)12 : AIC Calculated =280.59149248417424
# ARIMA (1, 0, 2) x (0, 0, 0, 12)12 : AIC Calculated =995.8367261740818
# ARIMA (1, 0, 2) x (0, 0, 1, 12)12 : AIC Calculated =807.5245150795041
# ARIMA (1, 0, 2) x (0, 1, 0, 12)12 : AIC Calculated =867.2148022511889
# ARIMA (1, 0, 2) x (0, 1, 1, 12)12 : AIC Calculated =727.086788539634
# ARIMA (1, 0, 2) x (0, 2, 0, 12)12 : AIC Calculated =698.6420922028625
# ARIMA (1, 0, 2) x (0, 2, 1, 12)12 : AIC Calculated =972.091785363048
# ARIMA (1, 0, 2) x (1, 0, 0, 12)12 : AIC Calculated =839.03217735271
# ARIMA (1, 0, 2) x (1, 0, 1, 12)12 : AIC Calculated =809.5866682060567
# ARIMA (1, 0, 2) x (1, 1, 0, 12)12 : AIC Calculated =677.0817761638456
# ARIMA (1, 0, 2) x (1, 1, 1, 12)12 : AIC Calculated =683.5655440307515
# ARIMA (1, 0, 2) x (1, 2, 0, 12)12 : AIC Calculated =505.37509498483985
# ARIMA (1, 0, 2) x (1, 2, 1, 12)12 : AIC Calculated =474.6616728170409
# ARIMA (1, 0, 2) x (2, 0, 0, 12)12 : AIC Calculated =652.5319195576047
# ARIMA (1, 0, 2) x (2, 0, 1, 12)12 : AIC Calculated =669.4616495064911
# ARIMA (1, 0, 2) x (2, 1, 0, 12)12 : AIC Calculated =474.14934724289026
# ARIMA (1, 0, 2) x (2, 1, 1, 12)12 : AIC Calculated =490.5738527977766
# ARIMA (1, 0, 2) x (2, 2, 0, 12)12 : AIC Calculated =284.95010521566724
# ARIMA (1, 0, 2) x (2, 2, 1, 12)12 : AIC Calculated =286.01059872298885
# ARIMA (1, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =1045.9580900784133
# ARIMA (1, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =851.5128728820623
# ARIMA (1, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =870.4381850536641
# ARIMA (1, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =669.8933561360205
# ARIMA (1, 1, 0) x (0, 2, 0, 12)12 : AIC Calculated =703.6668572700504
# ARIMA (1, 1, 0) x (0, 2, 1, 12)12 : AIC Calculated =1154.4891978072287
# ARIMA (1, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =851.6307618142905
# ARIMA (1, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =853.5101957728282
# ARIMA (1, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =666.8593858839289
# ARIMA (1, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =698.5798836420021
# ARIMA (1, 1, 0) x (1, 2, 0, 12)12 : AIC Calculated =476.26660099314984
# ARIMA (1, 1, 0) x (1, 2, 1, 12)12 : AIC Calculated =1074.3184205628995
# ARIMA (1, 1, 0) x (2, 0, 0, 12)12 : AIC Calculated =654.7361369273228
# ARIMA (1, 1, 0) x (2, 0, 1, 12)12 : AIC Calculated =655.9604516893337
# ARIMA (1, 1, 0) x (2, 1, 0, 12)12 : AIC Calculated =460.5872495842996
# ARIMA (1, 1, 0) x (2, 1, 1, 12)12 : AIC Calculated =460.712471201733
# ARIMA (1, 1, 0) x (2, 2, 0, 12)12 : AIC Calculated =256.54206435947464
# ARIMA (1, 1, 0) x (2, 2, 1, 12)12 : AIC Calculated =645.99483309116
# ARIMA (1, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =1024.8181674229568
# ARIMA (1, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =819.9337914725703
# ARIMA (1, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =853.7744110835775
# ARIMA (1, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =646.6042188740594
# ARIMA (1, 1, 1) x (0, 2, 0, 12)12 : AIC Calculated =686.0640936581538
# ARIMA (1, 1, 1) x (0, 2, 1, 12)12 : AIC Calculated =1012.2693938245397
# ARIMA (1, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =835.5566969097239
# ARIMA (1, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =821.5407458717705
# ARIMA (1, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =663.6241334404428
# ARIMA (1, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =652.4448452505242
# ARIMA (1, 1, 1) x (1, 2, 0, 12)12 : AIC Calculated =478.85890288400896
# ARIMA (1, 1, 1) x (1, 2, 1, 12)12 : AIC Calculated =1058.2880009407027
# ARIMA (1, 1, 1) x (2, 0, 0, 12)12 : AIC Calculated =656.665301179498
# ARIMA (1, 1, 1) x (2, 0, 1, 12)12 : AIC Calculated =661.244569979862
# ARIMA (1, 1, 1) x (2, 1, 0, 12)12 : AIC Calculated =468.39781047781537
# ARIMA (1, 1, 1) x (2, 1, 1, 12)12 : AIC Calculated =461.3857324596262
# ARIMA (1, 1, 1) x (2, 2, 0, 12)12 : AIC Calculated =258.56418343843643
# ARIMA (1, 1, 1) x (2, 2, 1, 12)12 : AIC Calculated =548.7743870054468
# ARIMA (1, 1, 2) x (0, 0, 0, 12)12 : AIC Calculated =995.0975598791905
# ARIMA (1, 1, 2) x (0, 0, 1, 12)12 : AIC Calculated =799.1028918676342
# ARIMA (1, 1, 2) x (0, 1, 0, 12)12 : AIC Calculated =831.9800959150939
# ARIMA (1, 1, 2) x (0, 1, 1, 12)12 : AIC Calculated =622.480280811759
# ARIMA (1, 1, 2) x (0, 2, 0, 12)12 : AIC Calculated =667.1351015260801
# ARIMA (1, 1, 2) x (0, 2, 1, 12)12 : AIC Calculated =791.2815473633309
# ARIMA (1, 1, 2) x (1, 0, 0, 12)12 : AIC Calculated =830.665041529904
# ARIMA (1, 1, 2) x (1, 0, 1, 12)12 : AIC Calculated =800.833762636689
# ARIMA (1, 1, 2) x (1, 1, 0, 12)12 : AIC Calculated =670.0165039054606
# ARIMA (1, 1, 2) x (1, 1, 1, 12)12 : AIC Calculated =647.4044393725454
# ARIMA (1, 1, 2) x (1, 2, 0, 12)12 : AIC Calculated =480.35612508076497
# ARIMA (1, 1, 2) x (1, 2, 1, 12)12 : AIC Calculated =974.8979111206106
# ARIMA (1, 1, 2) x (2, 0, 0, 12)12 : AIC Calculated =650.7568004031191
# ARIMA (1, 1, 2) x (2, 0, 1, 12)12 : AIC Calculated =651.5987970909441
# ARIMA (1, 1, 2) x (2, 1, 0, 12)12 : AIC Calculated =463.1037447379774
# ARIMA (1, 1, 2) x (2, 1, 1, 12)12 : AIC Calculated =463.19788934351124
# ARIMA (1, 1, 2) x (2, 2, 0, 12)12 : AIC Calculated =259.4934514567475
# ARIMA (1, 1, 2) x (2, 2, 1, 12)12 : AIC Calculated =571.8495688863825
# ARIMA (1, 2, 0) x (0, 0, 0, 12)12 : AIC Calculated =1025.429443105273
# ARIMA (1, 2, 0) x (0, 0, 1, 12)12 : AIC Calculated =832.0012312222445
# ARIMA (1, 2, 0) x (0, 1, 0, 12)12 : AIC Calculated =859.1836858752636
# ARIMA (1, 2, 0) x (0, 1, 1, 12)12 : AIC Calculated =656.5423361764415
# ARIMA (1, 2, 0) x (0, 2, 0, 12)12 : AIC Calculated =691.0184370378275
# ARIMA (1, 2, 0) x (0, 2, 1, 12)12 : AIC Calculated =1052.631694886385
# ARIMA (1, 2, 0) x (1, 0, 0, 12)12 : AIC Calculated =832.1098332185528
# ARIMA (1, 2, 0) x (1, 0, 1, 12)12 : AIC Calculated =834.0944127820798
# ARIMA (1, 2, 0) x (1, 1, 0, 12)12 : AIC Calculated =651.3218737151191
# ARIMA (1, 2, 0) x (1, 1, 1, 12)12 : AIC Calculated =654.7847461835204
# ARIMA (1, 2, 0) x (1, 2, 0, 12)12 : AIC Calculated =460.88408205855904
# ARIMA (1, 2, 0) x (1, 2, 1, 12)12 : AIC Calculated =954.0298749775349
# ARIMA (1, 2, 0) x (2, 0, 0, 12)12 : AIC Calculated =635.0936847427358
# ARIMA (1, 2, 0) x (2, 0, 1, 12)12 : AIC Calculated =635.5078401732391
# ARIMA (1, 2, 0) x (2, 1, 0, 12)12 : AIC Calculated =446.31538746938503
# ARIMA (1, 2, 0) x (2, 1, 1, 12)12 : AIC Calculated =451.5398750216417
# ARIMA (1, 2, 0) x (2, 2, 0, 12)12 : AIC Calculated =239.9868136138966
# ARIMA (1, 2, 0) x (2, 2, 1, 12)12 : AIC Calculated =244.65438447444626
# ARIMA (1, 2, 1) x (0, 0, 0, 12)12 : AIC Calculated =1001.0388430885829
# ARIMA (1, 2, 1) x (0, 0, 1, 12)12 : AIC Calculated =806.8583822642466
# ARIMA (1, 2, 1) x (0, 1, 0, 12)12 : AIC Calculated =841.7246443621484
# ARIMA (1, 2, 1) x (0, 1, 1, 12)12 : AIC Calculated =635.3647235565348
# ARIMA (1, 2, 1) x (0, 2, 0, 12)12 : AIC Calculated =672.9800347123638
# ARIMA (1, 2, 1) x (0, 2, 1, 12)12 : AIC Calculated =1051.0540550019807
# ARIMA (1, 2, 1) x (1, 0, 0, 12)12 : AIC Calculated =823.4599289839334
# ARIMA (1, 2, 1) x (1, 0, 1, 12)12 : AIC Calculated =808.5550095050187
# ARIMA (1, 2, 1) x (1, 1, 0, 12)12 : AIC Calculated =653.2776432467531
# ARIMA (1, 2, 1) x (1, 1, 1, 12)12 : AIC Calculated =638.9481653420022
# ARIMA (1, 2, 1) x (1, 2, 0, 12)12 : AIC Calculated =464.42067203558724
# ARIMA (1, 2, 1) x (1, 2, 1, 12)12 : AIC Calculated =905.759282988415
# ARIMA (1, 2, 1) x (2, 0, 0, 12)12 : AIC Calculated =635.563962529685
# ARIMA (1, 2, 1) x (2, 0, 1, 12)12 : AIC Calculated =635.7735725029607
# ARIMA (1, 2, 1) x (2, 1, 0, 12)12 : AIC Calculated =441.89046122084795
# ARIMA (1, 2, 1) x (2, 1, 1, 12)12 : AIC Calculated =453.5872410526343
# ARIMA (1, 2, 1) x (2, 2, 0, 12)12 : AIC Calculated =238.51720107106826
# ARIMA (1, 2, 1) x (2, 2, 1, 12)12 : AIC Calculated =238.16032629335706
# ARIMA (1, 2, 2) x (0, 0, 0, 12)12 : AIC Calculated =985.3756782931424
# ARIMA (1, 2, 2) x (0, 0, 1, 12)12 : AIC Calculated =786.9175239920011
# ARIMA (1, 2, 2) x (0, 1, 0, 12)12 : AIC Calculated =822.4570623591782
# ARIMA (1, 2, 2) x (0, 1, 1, 12)12 : AIC Calculated =615.699243575421
# ARIMA (1, 2, 2) x (0, 2, 0, 12)12 : AIC Calculated =653.8894877096661
# ARIMA (1, 2, 2) x (0, 2, 1, 12)12 : AIC Calculated =1008.9318332625746
# ARIMA (1, 2, 2) x (1, 0, 0, 12)12 : AIC Calculated =817.8356882615901
# ARIMA (1, 2, 2) x (1, 0, 1, 12)12 : AIC Calculated =788.6982145461815
# ARIMA (1, 2, 2) x (1, 1, 0, 12)12 : AIC Calculated =652.3507165642638
# ARIMA (1, 2, 2) x (1, 1, 1, 12)12 : AIC Calculated =628.0610373726709
# ARIMA (1, 2, 2) x (1, 2, 0, 12)12 : AIC Calculated =464.97440079200544
# ARIMA (1, 2, 2) x (1, 2, 1, 12)12 : AIC Calculated =899.1102182855435
# ARIMA (1, 2, 2) x (2, 0, 0, 12)12 : AIC Calculated =629.1652648242001
# ARIMA (1, 2, 2) x (2, 0, 1, 12)12 : AIC Calculated =635.3986780016381
# ARIMA (1, 2, 2) x (2, 1, 0, 12)12 : AIC Calculated =441.71722513329865
# ARIMA (1, 2, 2) x (2, 1, 1, 12)12 : AIC Calculated =452.3493790097173
# ARIMA (1, 2, 2) x (2, 2, 0, 12)12 : AIC Calculated =243.4548189764705
# ARIMA (1, 2, 2) x (2, 2, 1, 12)12 : AIC Calculated =245.53717582102868
# ARIMA (2, 0, 0) x (0, 0, 0, 12)12 : AIC Calculated =1045.3365828551855
# ARIMA (2, 0, 0) x (0, 0, 1, 12)12 : AIC Calculated =909.5556417900789
# ARIMA (2, 0, 0) x (0, 1, 0, 12)12 : AIC Calculated =871.7747861419227
# ARIMA (2, 0, 0) x (0, 1, 1, 12)12 : AIC Calculated =691.4162972415047
# ARIMA (2, 0, 0) x (0, 2, 0, 12)12 : AIC Calculated =701.8556222238182
# ARIMA (2, 0, 0) x (0, 2, 1, 12)12 : AIC Calculated =1029.1786456892005
# ARIMA (2, 0, 0) x (1, 0, 0, 12)12 : AIC Calculated =851.924601322252
# ARIMA (2, 0, 0) x (1, 0, 1, 12)12 : AIC Calculated =894.867601225169
# ARIMA (2, 0, 0) x (1, 1, 0, 12)12 : AIC Calculated =668.6531410869078
# ARIMA (2, 0, 0) x (1, 1, 1, 12)12 : AIC Calculated =704.137113868177
# ARIMA (2, 0, 0) x (1, 2, 0, 12)12 : AIC Calculated =477.0720243239269
# ARIMA (2, 0, 0) x (1, 2, 1, 12)12 : AIC Calculated =478.4769885406001
# ARIMA (2, 0, 0) x (2, 0, 0, 12)12 : AIC Calculated =655.8453601166764
# ARIMA (2, 0, 0) x (2, 0, 1, 12)12 : AIC Calculated =679.5805313341967
# ARIMA (2, 0, 0) x (2, 1, 0, 12)12 : AIC Calculated =462.4444255134767
# ARIMA (2, 0, 0) x (2, 1, 1, 12)12 : AIC Calculated =485.9963528033139
# ARIMA (2, 0, 0) x (2, 2, 0, 12)12 : AIC Calculated =250.5338934218442
# ARIMA (2, 0, 0) x (2, 2, 1, 12)12 : AIC Calculated =252.51087907391562
# ARIMA (2, 0, 1) x (0, 0, 0, 12)12 : AIC Calculated =1049.6886672367223
# ARIMA (2, 0, 1) x (0, 0, 1, 12)12 : AIC Calculated =832.9281822236759
# ARIMA (2, 0, 1) x (0, 1, 0, 12)12 : AIC Calculated =873.7604080941061
# ARIMA (2, 0, 1) x (0, 1, 1, 12)12 : AIC Calculated =834.1687079563255
# ARIMA (2, 0, 1) x (0, 2, 0, 12)12 : AIC Calculated =703.712152306799
# ARIMA (2, 0, 1) x (0, 2, 1, 12)12 : AIC Calculated =1161.091038469653
# ARIMA (2, 0, 1) x (1, 0, 0, 12)12 : AIC Calculated =832.931376809789
# ARIMA (2, 0, 1) x (1, 0, 1, 12)12 : AIC Calculated =863.17598953076
# ARIMA (2, 0, 1) x (1, 1, 0, 12)12 : AIC Calculated =670.214812496949
# ARIMA (2, 0, 1) x (1, 1, 1, 12)12 : AIC Calculated =726.9493781009505
# ARIMA (2, 0, 1) x (1, 2, 0, 12)12 : AIC Calculated =478.79363086287657
# ARIMA (2, 0, 1) x (1, 2, 1, 12)12 : AIC Calculated =480.4000067057116
# ARIMA (2, 0, 1) x (2, 0, 0, 12)12 : AIC Calculated =646.1119641376373
# ARIMA (2, 0, 1) x (2, 0, 1, 12)12 : AIC Calculated =646.59611003616
# ARIMA (2, 0, 1) x (2, 1, 0, 12)12 : AIC Calculated =455.6102439584732
# ARIMA (2, 0, 1) x (2, 1, 1, 12)12 : AIC Calculated =485.79539564491876
# ARIMA (2, 0, 1) x (2, 2, 0, 12)12 : AIC Calculated =251.15182412677456
# ARIMA (2, 0, 1) x (2, 2, 1, 12)12 : AIC Calculated =257.0012917966713
# ARIMA (2, 0, 2) x (0, 0, 0, 12)12 : AIC Calculated =992.9305190809181
# ARIMA (2, 0, 2) x (0, 0, 1, 12)12 : AIC Calculated =806.03218627545
# ARIMA (2, 0, 2) x (0, 1, 0, 12)12 : AIC Calculated =858.1851338782886
# ARIMA (2, 0, 2) x (0, 1, 1, 12)12 : AIC Calculated =777.5621256074367
# ARIMA (2, 0, 2) x (0, 2, 0, 12)12 : AIC Calculated =687.6650363880904
# ARIMA (2, 0, 2) x (0, 2, 1, 12)12 : AIC Calculated =1132.0846944446264
# ARIMA (2, 0, 2) x (1, 0, 0, 12)12 : AIC Calculated =821.3837094502437
# ARIMA (2, 0, 2) x (1, 0, 1, 12)12 : AIC Calculated =807.4474952736076
# ARIMA (2, 0, 2) x (1, 1, 0, 12)12 : AIC Calculated =658.8911624926487
# ARIMA (2, 0, 2) x (1, 1, 1, 12)12 : AIC Calculated =677.4009717578219
# ARIMA (2, 0, 2) x (1, 2, 0, 12)12 : AIC Calculated =484.50956912051316
# ARIMA (2, 0, 2) x (1, 2, 1, 12)12 : AIC Calculated =461.97246147506036
# ARIMA (2, 0, 2) x (2, 0, 0, 12)12 : AIC Calculated =636.0455272336528
# ARIMA (2, 0, 2) x (2, 0, 1, 12)12 : AIC Calculated =639.3079543214044
# ARIMA (2, 0, 2) x (2, 1, 0, 12)12 : AIC Calculated =454.7013132927394
# ARIMA (2, 0, 2) x (2, 1, 1, 12)12 : AIC Calculated =472.6219541370521
# ARIMA (2, 0, 2) x (2, 2, 0, 12)12 : AIC Calculated =260.5491100398132
# ARIMA (2, 0, 2) x (2, 2, 1, 12)12 : AIC Calculated =260.7466836406248
# ARIMA (2, 1, 0) x (0, 0, 0, 12)12 : AIC Calculated =1022.9021488544513
# ARIMA (2, 1, 0) x (0, 0, 1, 12)12 : AIC Calculated =846.3713696362618
# ARIMA (2, 1, 0) x (0, 1, 0, 12)12 : AIC Calculated =851.1608689236205
# ARIMA (2, 1, 0) x (0, 1, 1, 12)12 : AIC Calculated =667.9489146091018
# ARIMA (2, 1, 0) x (0, 2, 0, 12)12 : AIC Calculated =686.4859413661947
# ARIMA (2, 1, 0) x (0, 2, 1, 12)12 : AIC Calculated =1011.3872699760036
# ARIMA (2, 1, 0) x (1, 0, 0, 12)12 : AIC Calculated =830.6915725861636
# ARIMA (2, 1, 0) x (1, 0, 1, 12)12 : AIC Calculated =832.3649206120424
# ARIMA (2, 1, 0) x (1, 1, 0, 12)12 : AIC Calculated =642.890609296564
# ARIMA (2, 1, 0) x (1, 1, 1, 12)12 : AIC Calculated =672.4822455573044
# ARIMA (2, 1, 0) x (1, 2, 0, 12)12 : AIC Calculated =457.19883316681523
# ARIMA (2, 1, 0) x (1, 2, 1, 12)12 : AIC Calculated =946.9532020643359
# ARIMA (2, 1, 0) x (2, 0, 0, 12)12 : AIC Calculated =635.7076023740051
# ARIMA (2, 1, 0) x (2, 0, 1, 12)12 : AIC Calculated =637.6021069121609
# ARIMA (2, 1, 0) x (2, 1, 0, 12)12 : AIC Calculated =438.88670569714975
# ARIMA (2, 1, 0) x (2, 1, 1, 12)12 : AIC Calculated =440.3675796638086
# ARIMA (2, 1, 0) x (2, 2, 0, 12)12 : AIC Calculated =236.35331511223933
# ARIMA (2, 1, 0) x (2, 2, 1, 12)12 : AIC Calculated =516.4559219066186
# ARIMA (2, 1, 1) x (0, 0, 0, 12)12 : AIC Calculated =1014.4605214773288
# ARIMA (2, 1, 1) x (0, 0, 1, 12)12 : AIC Calculated =821.7835848924025
# ARIMA (2, 1, 1) x (0, 1, 0, 12)12 : AIC Calculated =858.8665314274903
# ARIMA (2, 1, 1) x (0, 1, 1, 12)12 : AIC Calculated =647.5903641310391
# ARIMA (2, 1, 1) x (0, 2, 0, 12)12 : AIC Calculated =689.4690820908959
# ARIMA (2, 1, 1) x (0, 2, 1, 12)12 : AIC Calculated =nan
# ARIMA (2, 1, 1) x (1, 0, 0, 12)12 : AIC Calculated =821.7380555030949
# ARIMA (2, 1, 1) x (1, 0, 1, 12)12 : AIC Calculated =823.2192453887105
# ARIMA (2, 1, 1) x (1, 1, 0, 12)12 : AIC Calculated =650.4573071870889
# ARIMA (2, 1, 1) x (1, 1, 1, 12)12 : AIC Calculated =649.584216192967
# ARIMA (2, 1, 1) x (1, 2, 0, 12)12 : AIC Calculated =462.93956474583456
# ARIMA (2, 1, 1) x (1, 2, 1, 12)12 : AIC Calculated =1026.552388533754
# ARIMA (2, 1, 1) x (2, 0, 0, 12)12 : AIC Calculated =630.9107386134526
# ARIMA (2, 1, 1) x (2, 0, 1, 12)12 : AIC Calculated =632.9663561918277
# ARIMA (2, 1, 1) x (2, 1, 0, 12)12 : AIC Calculated =446.733664867327
# ARIMA (2, 1, 1) x (2, 1, 1, 12)12 : AIC Calculated =446.97497510663754
# ARIMA (2, 1, 1) x (2, 2, 0, 12)12 : AIC Calculated =241.3138708641354
# ARIMA (2, 1, 1) x (2, 2, 1, 12)12 : AIC Calculated =1038.6751809307486
# ARIMA (2, 1, 2) x (0, 0, 0, 12)12 : AIC Calculated =1003.2721053771098
# ARIMA (2, 1, 2) x (0, 0, 1, 12)12 : AIC Calculated =804.3506034004108
# ARIMA (2, 1, 2) x (0, 1, 0, 12)12 : AIC Calculated =833.9495546722434
# ARIMA (2, 1, 2) x (0, 1, 1, 12)12 : AIC Calculated =622.1028887820487
# ARIMA (2, 1, 2) x (0, 2, 0, 12)12 : AIC Calculated =668.9610178802895
# ARIMA (2, 1, 2) x (0, 2, 1, 12)12 : AIC Calculated =1009.370107208864
# ARIMA (2, 1, 2) x (1, 0, 0, 12)12 : AIC Calculated =819.8831806058349
# ARIMA (2, 1, 2) x (1, 0, 1, 12)12 : AIC Calculated =806.3319428618295
# ARIMA (2, 1, 2) x (1, 1, 0, 12)12 : AIC Calculated =645.7942847706536
# ARIMA (2, 1, 2) x (1, 1, 1, 12)12 : AIC Calculated =639.630444116973
# ARIMA (2, 1, 2) x (1, 2, 0, 12)12 : AIC Calculated =461.9042607527198
# ARIMA (2, 1, 2) x (1, 2, 1, 12)12 : AIC Calculated =954.6946274305448
# ARIMA (2, 1, 2) x (2, 0, 0, 12)12 : AIC Calculated =631.4123167065555
# ARIMA (2, 1, 2) x (2, 0, 1, 12)12 : AIC Calculated =633.4030158334023
# ARIMA (2, 1, 2) x (2, 1, 0, 12)12 : AIC Calculated =434.8443599870987
# ARIMA (2, 1, 2) x (2, 1, 1, 12)12 : AIC Calculated =437.21615015323306
# ARIMA (2, 1, 2) x (2, 2, 0, 12)12 : AIC Calculated =243.98354772625362
# ARIMA (2, 1, 2) x (2, 2, 1, 12)12 : AIC Calculated =530.0820360342069
# ARIMA (2, 2, 0) x (0, 0, 0, 12)12 : AIC Calculated =988.8204800367173
# ARIMA (2, 2, 0) x (0, 0, 1, 12)12 : AIC Calculated =812.8537440613173
# ARIMA (2, 2, 0) x (0, 1, 0, 12)12 : AIC Calculated =829.7076265668068
# ARIMA (2, 2, 0) x (0, 1, 1, 12)12 : AIC Calculated =649.9027764310434
# ARIMA (2, 2, 0) x (0, 2, 0, 12)12 : AIC Calculated =662.5273744943565
# ARIMA (2, 2, 0) x (0, 2, 1, 12)12 : AIC Calculated =940.8878754989519
# ARIMA (2, 2, 0) x (1, 0, 0, 12)12 : AIC Calculated =796.0243500808161
# ARIMA (2, 2, 0) x (1, 0, 1, 12)12 : AIC Calculated =797.2596430703966
# ARIMA (2, 2, 0) x (1, 1, 0, 12)12 : AIC Calculated =623.3265537730535
# ARIMA (2, 2, 0) x (1, 1, 1, 12)12 : AIC Calculated =626.9925089814269
# ARIMA (2, 2, 0) x (1, 2, 0, 12)12 : AIC Calculated =435.64098061186564
# ARIMA (2, 2, 0) x (1, 2, 1, 12)12 : AIC Calculated =759.8899717032867
# ARIMA (2, 2, 0) x (2, 0, 0, 12)12 : AIC Calculated =605.9949476142036
# ARIMA (2, 2, 0) x (2, 0, 1, 12)12 : AIC Calculated =608.5697307506928
# ARIMA (2, 2, 0) x (2, 1, 0, 12)12 : AIC Calculated =418.7647098539759
# ARIMA (2, 2, 0) x (2, 1, 1, 12)12 : AIC Calculated =435.13253869370794
# ARIMA (2, 2, 0) x (2, 2, 0, 12)12 : AIC Calculated =218.96582283898007
# ARIMA (2, 2, 0) x (2, 2, 1, 12)12 : AIC Calculated =221.0886615795907
# ARIMA (2, 2, 1) x (0, 0, 0, 12)12 : AIC Calculated =990.4394619994431
# ARIMA (2, 2, 1) x (0, 0, 1, 12)12 : AIC Calculated =797.1119690473765
# ARIMA (2, 2, 1) x (0, 1, 0, 12)12 : AIC Calculated =831.7158917514163
# ARIMA (2, 2, 1) x (0, 1, 1, 12)12 : AIC Calculated =630.9963349169409
# ARIMA (2, 2, 1) x (0, 2, 0, 12)12 : AIC Calculated =663.9908634284435
# ARIMA (2, 2, 1) x (0, 2, 1, 12)12 : AIC Calculated =1038.830574856027
# ARIMA (2, 2, 1) x (1, 0, 0, 12)12 : AIC Calculated =797.8228204448042
# ARIMA (2, 2, 1) x (1, 0, 1, 12)12 : AIC Calculated =798.4164774908006
# ARIMA (2, 2, 1) x (1, 1, 0, 12)12 : AIC Calculated =624.095120049063
# ARIMA (2, 2, 1) x (1, 1, 1, 12)12 : AIC Calculated =644.1527961234424
# ARIMA (2, 2, 1) x (1, 2, 0, 12)12 : AIC Calculated =437.39405300610895
# ARIMA (2, 2, 1) x (1, 2, 1, 12)12 : AIC Calculated =912.1179069422865
# ARIMA (2, 2, 1) x (2, 0, 0, 12)12 : AIC Calculated =607.5145808241207
# ARIMA (2, 2, 1) x (2, 0, 1, 12)12 : AIC Calculated =609.4615958237174
# ARIMA (2, 2, 1) x (2, 1, 0, 12)12 : AIC Calculated =417.2576500406524
# ARIMA (2, 2, 1) x (2, 1, 1, 12)12 : AIC Calculated =431.17844531342587
# ARIMA (2, 2, 1) x (2, 2, 0, 12)12 : AIC Calculated =222.47983505940215
# ARIMA (2, 2, 1) x (2, 2, 1, 12)12 : AIC Calculated =224.3665157295115
# ARIMA (2, 2, 2) x (0, 0, 0, 12)12 : AIC Calculated =975.06125647303
# ARIMA (2, 2, 2) x (0, 0, 1, 12)12 : AIC Calculated =781.7962311989138
# ARIMA (2, 2, 2) x (0, 1, 0, 12)12 : AIC Calculated =811.9557299677083
# ARIMA (2, 2, 2) x (0, 1, 1, 12)12 : AIC Calculated =610.6918336570265
# ARIMA (2, 2, 2) x (0, 2, 0, 12)12 : AIC Calculated =645.3166761323563
# ARIMA (2, 2, 2) x (0, 2, 1, 12)12 : AIC Calculated =982.8368549763977
# ARIMA (2, 2, 2) x (1, 0, 0, 12)12 : AIC Calculated =799.7574579415925
# ARIMA (2, 2, 2) x (1, 0, 1, 12)12 : AIC Calculated =783.7394303904123
# ARIMA (2, 2, 2) x (1, 1, 0, 12)12 : AIC Calculated =627.2766354321715
# ARIMA (2, 2, 2) x (1, 1, 1, 12)12 : AIC Calculated =608.9818667441837
# ARIMA (2, 2, 2) x (1, 2, 0, 12)12 : AIC Calculated =436.58539808966185
# ARIMA (2, 2, 2) x (1, 2, 1, 12)12 : AIC Calculated =842.4109652454187
# ARIMA (2, 2, 2) x (2, 0, 0, 12)12 : AIC Calculated =608.5898780457484
# ARIMA (2, 2, 2) x (2, 0, 1, 12)12 : AIC Calculated =610.7282883198229
# ARIMA (2, 2, 2) x (2, 1, 0, 12)12 : AIC Calculated =418.8800537209878
# ARIMA (2, 2, 2) x (2, 1, 1, 12)12 : AIC Calculated =419.51987633584383
# ARIMA (2, 2, 2) x (2, 2, 0, 12)12 : AIC Calculated =224.12713259769083
# ARIMA (2, 2, 2) x (2, 2, 1, 12)12 : AIC Calculated =225.51061361717663

# %%
# Find the parameters with minimal AIC value
ans_df = pd.DataFrame(ans, columns=['pdq', 'pdqs', 'aic'])
ans_df.loc[ans_df['aic'].idxmin()]
# Out:
# pdq         (2, 2, 0)
# pdqs    (2, 2, 0, 12)
# aic           218.966
# Name: 448, dtype: object

# %%
# Plug the optimal parameter values into a new SARIMAX model
ARIMA_MODEL = sm.tsa.statespace.SARIMAX(zip_78721, 
                                        order=(2, 2, 0), 
                                        seasonal_order=(2, 2, 0, 12), 
                                        enforce_stationarity=False, 
                                        enforce_invertibility=False)

# Fit the model and print results
output = ARIMA_MODEL.fit()

print(output.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3591      0.447      0.804      0.422      -0.517       1.235
# ar.L2         -0.3258      0.329     -0.992      0.321      -0.970       0.318
# ar.S.L12      -0.9117      0.471     -1.934      0.053      -1.836       0.012
# ar.S.L24      -0.2447      0.979     -0.250      0.803      -2.163       1.673
# sigma2      2.139e+06   7.48e+05      2.862      0.004    6.74e+05     3.6e+06
# ==============================================================================

# %%
# Call plot_diagnostics() on the results calculated above 
output.plot_diagnostics(figsize=(15, 18))
plt.show()

# %%
# Get predictions starting from 01-01-1998 and calculate confidence intervals
pred = output.get_prediction(start=pd.to_datetime('2016-01-31'), dynamic=False)
pred_conf = pred.conf_int()

# %%
# Plot real vs predicted values along with confidence interval

rcParams['figure.figsize'] = 15, 6

# Plot observed values
ax = zip_78721['2013':].plot(label='observed')

# Plot predicted values
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=0.9)

# Plot the range for confidence intervals
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='g', alpha=0.5)

# Set axes labels
ax.set_xlabel('Date')
ax.set_ylabel('value')
plt.legend()

plt.show()

# %%
# Get the real and predicted values
zip_78721_forecasted = pred.predicted_mean
zip_78721_truth = zip_78721['value']['2016-01-31':]

# Compute the mean square error
mse = ((zip_78721_forecasted - zip_78721_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 78606697.26

# %%
# Get dynamic predictions with confidence intervals as above 
pred_dynamic = output.get_prediction(start=pd.to_datetime('2016-01-31'), dynamic=True, full_results=True)
pred_dynamic_conf = pred_dynamic.conf_int()

# %%
# Plot the dynamic forecast with confidence intervals.

ax = zip_78721['2013':].plot(label='observed', figsize=(20, 15))
pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_conf.index,
                pred_dynamic_conf.iloc[:, 0],
                pred_dynamic_conf.iloc[:, 1], color='g', alpha=.3)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2016-01-31'), zip_78721_forecasted.index[-1], alpha=.1, zorder=-1)

ax.set_xlabel('Date')
ax.set_ylabel('78721')

plt.legend()
plt.show()

# %%
# Get forecast 24 steps ahead in future
prediction = output.get_forecast(steps=24)

# Get confidence intervals of forecasts
pred_conf = prediction.conf_int()

# %%
# Plot future predictions with confidence intervals
ax = zip_78721.plot(label='observed', figsize=(20, 15))
prediction.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_conf.index,
                pred_conf.iloc[:, 0],
                pred_conf.iloc[:, 1], color='k', alpha=0.25)
ax.set_xlabel('Date')
ax.set_ylabel('78721 prices')

plt.legend()
plt.show()

# %%
pred_conf['mean'] = prediction.predicted_mean

pred_conf.head()
# Out:
#               lower value    upper value           mean
# 2018-05-31  294568.112962  300301.534875  297434.823919
# 2018-06-30  294452.671120  309143.297690  301797.984405
# 2018-07-31  292309.741064  317277.826661  304793.783862
# 2018-08-31  286268.643050  322154.612861  304211.627955
# 2018-09-30  278066.879413  325714.239507  301890.559460

# %%
roi_2 = (pred_conf.iloc[23][2] - pred_conf.iloc[0][2])/pred_conf.iloc[0][2] * 100
roi_2
# Out:
# -16.67624527141904

# %%
pred_roi_df = pd.DataFrame(columns=['zipcode', 'roi_2'])
pred_roi_df.loc[len(pred_roi_df.index)] = [78702, roi_2] 
pred_roi_df
# Out:
#    zipcode      roi_2
# 0  78702.0 -16.676245

# %%
zips_grouped.to_pickle("zips_grouped.pkl")
pred_roi_df.to_pickle("pred_roi_df.pkl")
